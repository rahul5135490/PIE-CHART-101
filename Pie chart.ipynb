# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
plt.pie(class1_students)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
plt.pie(class1_students, labels=classes)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%")
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
wedgeprops={"linewidth":4,"width":1,"edgecolor":"k"}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
wedgeprops={"linewidth":4,"width":1,"edgecolor":"k"}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops,center=(2,3))
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
wedgeprops={"linewidth":4,"width":1,"edgecolor":"k"}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops,center=(2,3),frame=True)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
wedgeprops={"linewidth":4,"width":1,"edgecolor":"k"}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops,center=(2,3),frame=True,rotatelabels=True)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
wedgeprops={"linewidth":6.4,"width":4,"edgecolor":"k"}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops,center=(2,3),frame=True,rotatelabels=True)
plt.show()

# %%
classes=["python","R","Scala","Power BI","Julia"]
class1_students=[45,45,60,55,15]
explode=[0.3,0,0,0,0]
textprops={"fontsize":15}
wedgeprops={"linewidth":4,"width":1,"edgecolor":"k"}
plt.pie(class1_students, labels=classes,explode=explode, autopct="%0.2f%%",shadow=True,radius=2.4,startangle=90,textprops=textprops,center=(2,3),frame=True,rotatelabels=True)
plt.legend()
plt.show()
